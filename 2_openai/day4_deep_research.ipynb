# %% [markdown]
# ## Deep Research
#
# One of the classic cross-business Agentic use cases! This is huge.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">A Deep Research agent is broadly applicable to any business area, and to your own day-to-day activities. You can make use of this yourself!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from agents import Agent, WebSearchTool, trace, Runner, function_tool
from agents.model_settings import ModelSettings
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import asyncio
from IPython.display import display, Markdown
from messenger import send_email, push

# %%
load_dotenv(override=True)
# Out:
# True

# %%
# Constants 

MODEL_NAME = "gpt-5.4-mini"
USE_EMAIL = False
HOW_MANY_SEARCHES = 5

# %% [markdown]
# ## Strategy for the Deep Research Agent
#
# We are going to do it the bulletproof way.
#
# We are going to orchestrate with code: separate calls to `Runner.run()` for each step in the process.
#
# We will use Structured Outputs at each point.
#
# ## We will build 4 Agents:
#
# 1. The Search Agent: searches the web for information
# 2. The Planner Agent: given a question, comes up with a list of searches that should be made
# 3. The Writer Agent: writes a robust report
# 4. The Emailer Agent: crafts and sends an email
#
# And then 4 python functions, 1 to call Runner.run() for each of the 4 agents.

# %% [markdown]
# ## Agent 1: The Search Agent

# %% [markdown]
# ### OpenAI Hosted Tools
#
# https://openai.github.io/openai-agents-python/tools/#hosted-tools
#
# A paid, quick approach to carrying out managed functionality on OpenAI's cloud.
#
# Their docs surface these tools, but it's worth keeping in mind that they're costly and lock you in to the OpenAI ecosystem.
#
# OpenAI offers the following hosted tools:
#
# `WebSearchTool` lets an agent search the web.
# `FileSearchTool` allows retrieving information from your OpenAI Vector Stores.
# `CodeInterpreterTool` lets the LLM execute code in a sandboxed environment.
# `HostedMCPTool` exposes a remote MCP server's tools to the model.
# `ImageGenerationTool` generates images from a prompt.
# `ToolSearchTool` lets the model load deferred tools, namespaces, or hosted MCP servers on demand.
#
# ### Important note - API charge of WebSearchTool
#
# This currently costs 1 cent per call for OpenAI WebSearchTool. That can add up to about $1 for the next 2 labs. We'll use free and low cost Search tools with other platforms, so feel free to skip running this if the cost is a concern. Also student Christian W. pointed out that OpenAI can sometimes charge for multiple searches for a single call, so it could sometimes cost more than 1 cent per call.
#
# Costs are in the Tools section here: https://developers.openai.com/api/docs/pricing

# %%
INSTRUCTIONS = """
You are a research assistant. Given a search term, you search the web for that term and 
produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words.
Capture the main points and be succinct. Reply only with the summary.
"""
task = "Most popular AI Agent frameworks in 2026"

settings = ModelSettings(tool_choice="required")
tools = [WebSearchTool()]

# %%
search_agent = Agent(name="Search Agent", instructions=INSTRUCTIONS, tools=tools, model=MODEL_NAME, model_settings=settings)

# %%
result = await Runner.run(search_agent, task)
display(Markdown(result.final_output))
# Out:
# As of 2026, the most popular AI agent frameworks appear to be **LangChain**, **AutoGen**, **CrewAI**, **LangGraph**, and the **OpenAI Agents SDK**, with **Google ADK**, **Microsoft Agent Framework**, and **Dify** also showing strong momentum. A June 2026 GitHub-curated comparison ranks LangChain as the largest by stars, followed by AutoGen and CrewAI, while noting LangGraph’s graph-based orchestration and the OpenAI Agents SDK’s minimal agent primitives as major differentiators. ([github.com](https://github.com/Anandesh-Sharma/awesome-agent-harnesses?utm_source=openai))
#
# Popularity in 2026 is no longer just about star counts: newer trackers highlight **production orientation, multi-agent orchestration, and governance/observability** as key selection criteria. LangChain remains the broad default for LLM app building, LangGraph is favored for stateful workflows, CrewAI for role-based multi-agent setups, and Microsoft’s new Agent Framework is positioned as a production-grade option across Python and .NET. GitHub trend trackers also show fast-growing interest in newer agent workflows and harnesses, including Dify and emerging framework experiments. ([github.com](https://github.com/duanyytop/agents-radar/issues/2511?utm_source=openai))

# %% [markdown]
# ### As always, take a look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Agent 2: The Planner Agent

# %% [markdown]
# ### We will now use Structured Outputs, and include a description of the fields

# %%
class WebSearchItem(BaseModel):
    reason: str = Field(description="Your reasoning for why this search is important to the query.")
    query: str = Field(description="The search term to use for the web search.")


class WebSearchPlan(BaseModel):
    searches: list[WebSearchItem] = Field(description="A list of web searches to perform to best answer the query.")

# %%
WebSearchPlan.model_json_schema()
# Out:
# {'$defs': {'WebSearchItem': {'properties': {'reason': {'description': 'Your reasoning for why this search is important to the query.',
#      'title': 'Reason',
#      'type': 'string'},
#     'query': {'description': 'The search term to use for the web search.',
#      'title': 'Query',
#      'type': 'string'}},
#    'required': ['reason', 'query'],
#    'title': 'WebSearchItem',
#    'type': 'object'}},
#  'properties': {'searches': {'description': 'A list of web searches to perform to best answer the query.',
#    'items': {'$ref': '#/$defs/WebSearchItem'},
#    'title': 'Searches',
#    'type': 'array'}},
#  'required': ['searches'],
#  'title': 'WebSearchPlan',
#  'type': 'object'}

# %%
# See note above about cost of WebSearchTool

INSTRUCTIONS = f"""
You are a research assistant. Given a user query, come up with a set of web searches
to perform to best answer the query. Output {HOW_MANY_SEARCHES} terms to query for.
"""

planner_agent = Agent(name="Planner Agent", instructions=INSTRUCTIONS, model=MODEL_NAME, output_type=WebSearchPlan)

# %%
result = await Runner.run(planner_agent, task)
result.final_output
# Out:
# WebSearchPlan(searches=[WebSearchItem(reason='Find current market/adoption discussions and rankings for AI agent frameworks in 2026.', query='most popular AI agent frameworks 2026'), WebSearchItem(reason='Compare developer usage and trend signals across agent frameworks.', query='AI agent framework popularity 2026 GitHub stars downloads'), WebSearchItem(reason='Identify up-to-date lists and benchmarks from industry sources covering agent orchestration tools.', query='best AI agent frameworks 2026 review comparison'), WebSearchItem(reason='Check enterprise and production-focused framework adoption trends.', query='enterprise AI agent frameworks 2026 LangGraph CrewAI AutoGen'), WebSearchItem(reason='Find community sentiment and mentions of newer frameworks emerging in 2026.', query='AI agent frameworks 2026 Reddit Hacker News discussions')])

# %% [markdown]
# ## Agent 3: The Writer Agent

# %%
INSTRUCTIONS = """
You are a senior researcher tasked with writing a cohesive report for a research query.
You will be provided with the original query, and some research.
Generate a comprehensive report based on the research and the query.
The final output should be in markdown format, and it should be lengthy and detailed. Aim 
for 5-10 pages of content, at least 1000 words.
"""


class ReportData(BaseModel):
    short_summary: str = Field(description="A short 2-3 sentence summary of the findings.")
    markdown_report: str = Field(description="The final report")
    follow_up_questions: list[str] = Field(description="Suggested topics to research further")


writer_agent = Agent(name="Writer Agent", instructions=INSTRUCTIONS, model=MODEL_NAME, output_type=ReportData)

# %% [markdown]
# ## Agent 4: The email agent

# %%
@function_tool
def send_email_tool(subject: str, text_body: str, html_body: str) -> str:
    """
    Send out an email with the given subject and body to all sales prospects
    
    Args:
        subject: The subject of the email
        text_body: The body of the email as plain text
        html_body: The HTML body of the email
    """
    if USE_EMAIL:
        send_email(subject, text_body, html_body)
    else:
        push(f"Subject: {subject}\n\n{text_body}")
    return "Email sent successfully"

# %%
send_email_tool.params_json_schema
# Out:
# {'properties': {'subject': {'description': 'The subject of the email',
#    'title': 'Subject',
#    'type': 'string'},
#   'text_body': {'description': 'The body of the email as plain text',
#    'title': 'Text Body',
#    'type': 'string'},
#   'html_body': {'description': 'The HTML body of the email',
#    'title': 'Html Body',
#    'type': 'string'}},
#  'required': ['subject', 'text_body', 'html_body'],
#  'title': 'send_email_tool_args',
#  'type': 'object',
#  'additionalProperties': False}

# %%
INSTRUCTIONS = """
You are provided with a detailed report. Use your tool to send an email, converting the report into
a clean, well presented HTML email with an appropriate subject line.
"""

email_agent = Agent(name="Email Agent", instructions=INSTRUCTIONS, tools=[send_email_tool], model=MODEL_NAME)

# %% [markdown]
# ## Now to Orchestrate by Code
#
# The next 2 functions will plan and execute the search, using the Agents, with calls to `Runner.run()`

# %%
async def run_searches(query: str):
    print("Planning searches...")
    result = await Runner.run(planner_agent, f"Query: {query}")
    searches = result.final_output.searches
    print(f"Will perform {len(searches)} searches")
    tasks = [search(item) for item in searches]
    results = await asyncio.gather(*tasks)
    print("Finished searching")
    return results


async def search(item: WebSearchItem):
    input_message = f"Search term: {item.query}\nReason for searching: {item.reason}"
    result = await Runner.run(search_agent, input_message)
    return result.final_output

# %% [markdown]
# The next 2 functions write a report and email it

# %%
async def write_report(query: str, search_results: list[str]):
    print("Thinking about report...")
    input_message = f"Original query: {query}\nSummarized search results: {search_results}"
    result = await Runner.run(writer_agent, input_message)
    print("Finished writing report")
    return result.final_output

async def send_report_email(report: ReportData):
    print("Writing email...")
    result = await Runner.run(email_agent, report.markdown_report)
    print("Email sent")
    return result.final_output

# %% [markdown]
# ### Showtime!

# %%
query ="Most popular AI Agent frameworks in 2026"

with trace("Research trace"):
    print("Starting research...")
    search_results = await run_searches(query)
    report = await write_report(query, search_results)
    await send_report_email(report)  
    print("Hooray!")
# Out:
# Starting research...
# Planning searches...
# Will perform 5 searches
# Finished searching
# Thinking about report...
# Finished writing report
# Writing email...
# Push: Subject: Most Popular AI Agent Frameworks in 2026 — Executive Report
#
# Most Popular AI Agent Frameworks in 2026
#
# Executive overview
#
# The AI agent framework landscape in 2026 has moved beyond early experimentation into a more practical, production-oriented phase. The most prominent frameworks are those that help developers build reliable, observable, and maintainable agents.
#
# Leading frameworks in 2026 include:
# - LangChain / LangGraph
# - CrewAI
# - AutoGen
# - LlamaIndex
# - Pydantic AI
# - OpenAI Agents SDK
# - Google ADK
# - Semantic Kernel / Microsoft Agent Framework
# - plus newer or adjacent tools such as Mastra, Vercel AI SDK, and smolagents in some comparisons
#
# Key takeaways:
# - LangGraph is widely treated as the default for stateful, production-grade orchestration.
# - CrewAI is popular for role-based, collaborative multi-agent workflows.
# - AutoGen remains a major reference point for multi-agent design.
# - LlamaIndex is especially strong for retrieval-augmented generation (RAG) and data-centric workflows.
# - OpenAI Agents SDK and Google ADK are gaining traction through deep ecosystem integration.
# - Pydantic AI is notable for type safety and Python-native ergonomics.
#
# How popularity is measured in 2026
#
# People increasingly use multiple indicators rather than a single metric:
# - GitHub stars and forks
# - Star velocity and recent activity
# - Release cadence and maintenance health
# - Survey and market usage signals
# - Ecosystem fit and production readiness
# - Vendor backing and first-party ecosystem integration
#
# Framework highlights
#
# LangChain / LangGraph
# - Strong ecosystem and brand recognition
# - Best fit for stateful and production-grade workflows
# - Useful for persistent state, branching, looping, checkpointing, and debugging
#
# CrewAI
# - Strong community adoption
# - Clear multi-agent abstractions
# - Good for collaborative task decomposition and rapid prototyping
#
# AutoGen
# - Major historical influence in multi-agent systems
# - Still widely recognized, though Microsoft’s newer framework direction is important
#
# LlamaIndex
# - Strong reputation in RAG and retrieval workflows
# - Commonly used alongside orchestration frameworks
#
# Pydantic AI
# - Python-friendly and type-safe
# - Good for structured workflows and maintainable codebases
#
# OpenAI Agents SDK
# - First-party OpenAI integration
# - Attractive for teams already standardizing on OpenAI APIs
#
# Google ADK
# - Strong alignment with Google’s model and cloud ecosystem
# - Especially relevant for Google Cloud users
#
# Semantic Kernel / Microsoft Agent Framework
# - Important for Microsoft-stack and enterprise teams
# - The ecosystem is evolving toward Microsoft Agent Framework
#
# Other frameworks mentioned in 2026 discussions:
# - Mastra
# - Vercel AI SDK
# - smolagents
# - AutoGPT
#
# Market pattern
#
# The market is shifting from demos to infrastructure. Popular frameworks in 2026 are increasingly optimized for:
# - reliability and durability
# - observability
# - checkpointing and workflow control
# - tool integration
# - governance and enterprise fit
# - simplicity where appropriate
#
# Practical ranking
#
# Broad mainstream recognition:
# 1. LangChain / LangGraph
# 2. CrewAI
# 3. AutoGen
# 4. LlamaIndex
#
# Rising or strategically important:
# 5. OpenAI Agents SDK
# 6. Google ADK
# 7. Pydantic AI
# 8. Semantic Kernel / Microsoft Agent Framework
#
# Specialized or situational:
# - Mastra
# - Vercel AI SDK
# - smolagents
# - AutoGPT
#
# Final conclusion
#
# In 2026, the most popular AI agent frameworks are the ones that balance adoption, usability, ecosystem breadth, and production readiness. There is no single universal winner; the best choice depends on your stack, deployment environment, and operational needs.
#
# Quick decision guide:
# - Production-grade orchestration: LangGraph
# - Role-based multi-agent teams: CrewAI
# - Classic multi-agent conversation patterns: AutoGen
# - Data/RAG-heavy agents: LlamaIndex
# - Python typing and structured outputs: Pydantic AI
# - Native OpenAI integration: OpenAI Agents SDK
# - Google ecosystem alignment: Google ADK
# - Microsoft enterprise alignment: Microsoft Agent Framework / Semantic Kernel transition path
# Email sent
# Hooray!

# %% [markdown]
# ### As always, take a look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thanks.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00cc00;">Congratulations on your progress, and a request</h2>
#             <span style="color:#00cc00;">You've reached an important moment with the course; you've created a valuable Agent using one of the latest Agent frameworks. You've upskilled, and unlocked new commercial possibilities. Take a moment to celebrate your success!<br/><br/>Something I should ask you -- my editor would smack me if I didn't mention this. If you're able to rate the course on Udemy, I'd be seriously grateful: it's the most important way that Udemy decides whether to show the course to others and it makes a massive difference.<br/><br/>And another reminder to <a href="https://www.linkedin.com/in/eddonner/">connect with me on LinkedIn</a> if you wish! If you wanted to post about your progress on the course, please tag me and I'll weigh in to increase your exposure.
#             </span>
#         </td>
#     </tr>
